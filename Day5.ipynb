# %% [markdown]
# --- Day 5: Supply Stacks ---
#
# The expedition can depart as soon as the final supplies have been unloaded from the ships. Supplies are stored in stacks of marked crates, but because the needed supplies are buried under many other crates, the crates need to be rearranged.
#
# The ship has a giant cargo crane capable of moving crates between stacks. To ensure none of the crates get crushed or fall over, the crane operator will rearrange them in a series of carefully-planned steps. After the crates are rearranged, the desired crates will be at the top of each stack.
#
# The Elves don't want to interrupt the crane operator during this delicate procedure, but they forgot to ask her which crate will end up where, and they want to be ready to unload them as soon as possible so they can embark.
#
# They do, however, have a drawing of the starting stacks of crates and the rearrangement procedure (your puzzle input). For example:
#
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2
#
# In this example, there are three stacks of crates. Stack 1 contains two crates: crate Z is on the bottom, and crate N is on top. Stack 2 contains three crates; from bottom to top, they are crates M, C, and D. Finally, stack 3 contains a single crate, P.
#
# Then, the rearrangement procedure is given. In each step of the procedure, a quantity of crates is moved from one stack to a different stack. In the first step of the above rearrangement procedure, one crate is moved from stack 2 to stack 1, resulting in this configuration:
#
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# In the second step, three crates are moved from stack 1 to stack 3. Crates are moved one at a time, so the first crate to be moved (D) ends up below the second and third crates:
#
#         [Z]
#         [N]
#     [C] [D]
#     [M] [P]
#  1   2   3
#
# Then, both crates are moved from stack 2 to stack 1. Again, because crates are moved one at a time, crate C ends up below crate M:
#
#         [Z]
#         [N]
# [M]     [D]
# [C]     [P]
#  1   2   3
#
# Finally, one crate is moved from stack 1 to stack 2:
#
#         [Z]
#         [N]
#         [D]
# [C] [M] [P]
#  1   2   3
#
# The Elves just need to know which crate will end up on top of each stack; in this example, the top crates are C in stack 1, M in stack 2, and Z in stack 3, so you should combine these together and give the Elves the message CMZ.
#
# After the rearrangement procedure completes, what crate ends up on top of each stack?

# %%
with open("Day5_input.txt", "r") as file:
    for line in file:
        if line.startswith(" 1"):
            column_number = int(line.strip("\n").strip()[-1])
    columns = [[] for i in range(column_number)]
    line_length = column_number * 3 + column_number - 1
    
with open("Day5_input.txt", "r") as file:  
    for line in file:
        if "[" in line:
            counter = 0
            while counter <= line_length:
                columns[int(counter / 4)].append(line[counter:counter+3])
                counter +=4

def remove_blanks(lst):
    return [item for item in lst if " " not in item]

columns = list(map(remove_blanks, columns))
columns = [column[::-1] for column in columns]
                
import re
with open("Day5_input.txt", "r") as file:
    for line in file:
        if line.startswith("move"):
            how_many, move_from, move_to = [int(number) for number in (re.findall(r"\d+", line))]
            print(f"taking {how_many} last crates from {columns[move_from-1]} to {columns[move_to-1]}")
            for crate in range(how_many):
                if len(columns[move_from-1]) > 0:
                    columns[move_to - 1].append(columns[move_from - 1].pop())
# Out:
# taking 2 last crates from ['[W]', '[J]', '[L]', '[T]', '[P]', '[M]', '[S]', '[H]'] to ['[N]', '[C]', '[R]']
# taking 3 last crates from ['[S]', '[Z]', '[P]', '[D]', '[L]', '[B]', '[F]', '[C]'] to ['[H]', '[T]', '[P]', '[M]', '[Q]', '[B]', '[W]']
# taking 2 last crates from ['[F]', '[W]', '[B]', '[J]', '[G]'] to ['[N]', '[C]', '[R]', '[H]', '[S]']
# taking 6 last crates from ['[N]', '[C]', '[R]', '[H]', '[S]', '[G]', '[J]'] to ['[W]', '[J]', '[L]', '[T]', '[P]', '[M]']
# taking 2 last crates from ['[F]', '[W]', '[B]'] to ['[F]', '[S]', '[W]', '[T]']
# taking 9 last crates from ['[H]', '[T]', '[P]', '[M]', '[Q]', '[B]', '[W]', '[C]', '[F]', '[B]'] to ['[F]', '[S]', '[W]', '[T]', '[B]', '[W]']
# taking 15 last crates from ['[F]', '[S]', '[W]', '[T]', '[B]', '[W]', '[B]', '[F]', '[C]', '[W]', '[B]', '[Q]', '[M]', '[P]', '[T]'] to ['[N]']
# taking 3 last crates from ['[S]', '[Z]', '[P]', '[D]', '[L]'] to ['[B]', '[C]', '[W]', '[G]', '[F]', '[S]']
# ...

# %%
"".join([column[-1].strip("[").strip("]") for column in columns])
# Out:
# 'FWSHSPJWM'

# %%
#multiple crates at once
with open("Day5_input.txt", "r") as file:
    for line in file:
        if line.startswith(" 1"):
            column_number = int(line.strip("\n").strip()[-1])
    columns = [[] for i in range(column_number)]
    line_length = column_number * 3 + column_number - 1
    
with open("Day5_input.txt", "r") as file:  
    for line in file:
        if "[" in line:
            counter = 0
            while counter <= line_length:
                columns[int(counter / 4)].append(line[counter:counter+3])
                counter +=4

def remove_blanks(lst):
    return [item for item in lst if " " not in item]

columns = list(map(remove_blanks, columns))
columns = [column[::-1] for column in columns]
                
import re
with open("Day5_input.txt", "r") as file:
    for line in file:
        if line.startswith("move"):
            how_many, move_from, move_to = [int(number) for number in (re.findall(r"\d+", line))]
            if len(columns[move_from-1]) > 0:
                crate_number = min(how_many, len(columns[move_from-1]))
                print(f"taking {crate_number} last crates from {columns[move_from-1]} to {columns[move_to-1]}")
                columns[move_to - 1].extend(columns[move_from-1][-crate_number:])
                columns[move_from - 1] = columns[move_from - 1][:-crate_number]
            else:
                print(f"Can't take any crates from {columns[move_from-1]}")
            #print(sum([len(column) for column in columns]))
# Out:
# taking 2 last crates from ['[W]', '[J]', '[L]', '[T]', '[P]', '[M]', '[S]', '[H]'] to ['[N]', '[C]', '[R]']
# taking 3 last crates from ['[S]', '[Z]', '[P]', '[D]', '[L]', '[B]', '[F]', '[C]'] to ['[H]', '[T]', '[P]', '[M]', '[Q]', '[B]', '[W]']
# taking 2 last crates from ['[F]', '[W]', '[B]', '[J]', '[G]'] to ['[N]', '[C]', '[R]', '[S]', '[H]']
# taking 6 last crates from ['[N]', '[C]', '[R]', '[S]', '[H]', '[J]', '[G]'] to ['[W]', '[J]', '[L]', '[T]', '[P]', '[M]']
# taking 2 last crates from ['[F]', '[W]', '[B]'] to ['[F]', '[S]', '[W]', '[T]']
# taking 9 last crates from ['[H]', '[T]', '[P]', '[M]', '[Q]', '[B]', '[W]', '[B]', '[F]', '[C]'] to ['[F]', '[S]', '[W]', '[T]', '[W]', '[B]']
# taking 15 last crates from ['[F]', '[S]', '[W]', '[T]', '[W]', '[B]', '[T]', '[P]', '[M]', '[Q]', '[B]', '[W]', '[B]', '[F]', '[C]'] to ['[N]']
# taking 3 last crates from ['[S]', '[Z]', '[P]', '[D]', '[L]'] to ['[B]', '[C]', '[W]', '[G]', '[F]', '[S]']
# ...

# %%
"".join([column[-1].strip("[").strip("]") for column in columns])
# Out:
# 'PWPWHGFZS'

# %%
columns[move_from-1][-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-194-177be5b6bdfa> in <module>
# ----> 1 columns[move_from-1][-1]
#
# IndexError: list index out of range

# %%
columns
# Out:
# [[], [], [], [], [], [], [], [']'], []]

# %%
[][-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-171-32065a7d8c95> in <module>
# ----> 1 [][-1]
#
# IndexError: list index out of range

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6, [2, 5]]

# %%
x.extend(["2", "5"])

# %%
# Out:
# []
